# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehwachung/Python-Programming/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_8%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 8강 2절

# %% [markdown]
# **리스트 원소 접근**

# %%
hei_list = [1, 5, 14, 26, 31]

# %% [markdown]
# **리스트 관련 연산자**

# %%
hei1 = [1, 5, 14, 26, 31]
hei2 = [1, 7, 15]

# %% [markdown]
# **리스트 관련 내장함수**

# %% [markdown]
# **리스트 주요 메소드**
#
# <img src="data:image/png;base64,..." width="500">

# %%
tech_stack = ["Python", "Java", "Docker", "Python",
              "Linux", "SQL", "Git", "AWS"]

# %% [markdown]
# **유효 평균값과 중앙값 구하기**
#
# <img src="data:image/png;base64,..." width="400">

# %%
# 점수 리스트
score = [9, 8, 10, 7, 9, 8, 10, 6, 9, 8, 7, 9, 10, 8, 9, 5, 8, 9, 7]

# %% [markdown]
# # 8강 3절

# %% [markdown]
# **리스트 슬라이싱**

# %%
hei_list = [1, 5, 14, 26, 31]

# %% [markdown]
# **리스트 컴프리헨션**

# %%
hei_list = [i for i in [1, 5, 14, 26, 31] ]

# %% [markdown]
# **유효 평균값과 중앙값 구하기**
#
# <img src="data:image/png;base64,..." width="450">

# %%
close = [
   9200,  10150,   9450,  11080,   9720,
  10430,   9150,  11240,   9860,  11890,
  10320,  12150,   9970,  11580,   9420,
  10960,   9050,  12040,  10010,  12580,
  10820,  11970,   9620,  11360,   9310,
  11190,   9840,  12320,  10180,  12850
]
threshold = 11000
