# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehwachung/Python-Programming/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_12%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 12강 파일 실습

# %% [markdown]
# **12강 2절 파일의 사용**

# %% [markdown]
# 파일 객체 생성 및 파일 읽기

# %%
#Jobs.txt 파일 업로드

# %% [markdown]
# 파일 쓰기와 추가하기

# %%
#pythonb.txt 파일 생성

# %% [markdown]
# 명언을 읽고 저자를 작성하는 프로그램
#
# 'Khan.txt' 파일을 읽은 후 파일의 모든 내용을 출력하고 파일의 마지막에 '-칭기스 칸-'을 삽입하시오.

# %%
# Khan.txt 파일 열기

# 파일 데이터 읽기

# 불필요 공백 제거 및 출력

# 파일 열기

# %% [markdown]
# **12강 3절 효과적 파일 처리**

# %% [markdown]
# 서버 로그 리포트 작성 프로그램
#
# 서버 로그를 읽고 HTML 형식으로 리포트를 작성하는 프로그램을 작성하시오.
#  - 응답시간이 50초 이상이면 배경을 주황색
#  - 레벨이 WARN이면 배경을 노란색
#
#
# <img src="data:image/png;base64,..." width="450">

# %%
# server_log_2026.csv 파일 업로드
# 파일 열기
s_fp = open("server_log_2026.csv", "r", encoding="utf-8")
t_fp = open("log_report.html", "w", encoding="utf-8")

t_fp.write("<html>\n<body>\n")
t_fp.write("<h2>2026년 서버 모니터링 리포트</h2>\n")
t_fp.write("<table border='1' cellspacing='0' cellpadding='5'>\n")

count = 0

# 파일 데이터 읽기

    # 불필요 공백 제거

    # 공백라인 스킵
    if line == "":
        continue

    # 데이터 분리

    # 배경색
    row_color = ""

    if row_color != "":

    else:

    if count == 0:

    else:


    t_fp.write("</tr>\n")
    count += 1

t_fp.write("</table>\n</body>\n</html>")

print("리포트 생성 완료!")
